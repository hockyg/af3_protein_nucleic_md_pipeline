# %%
import numpy as np  
import glob as glob
import os

# read in files to a dictionary based on file name results/{LABEL}_r{MUTANTID}_model_md.interactions.log
def read_files(files):
    data = {}
    for file in files:
        #label = os.path.basename(file).split('_')[0]
        #mutantid = file.split('_')[1][1:]
        #data[label + ":"+mutantid] = np.loadtxt(file, skiprows=1)
        label = "_".join(  os.path.basename(file).split("_")[:2] )
        #print(f"parsing {file}")
        try: 
            new_data = np.loadtxt(file, skiprows=1)
        except ValueError as e:
            print(f"Error parsing {file} {e}, skipping)")
            pass
        data[label] = new_data

    return data

results_dir = "output/validation_sequences_9Feb2025"

# read in the files from the results directory
files = glob.glob(os.path.join(results_dir,"*/*/md_implicit/*.interactions.log"))
data = read_files(files)
# Out:
# Error parsing output/validation_sequences_9Feb2025/p06876/p06876_mut8/md_implicit/p06876_mut8_model_md.interactions.log the number of columns changed from 5 to 1 at row 366; use `usecols` to select a subset and avoid this error, skipping)
# Error parsing output/validation_sequences_9Feb2025/p06876/p06876_mut17/md_implicit/p06876_mut17_model_md.interactions.log the number of columns changed from 5 to 1 at row 1508; use `usecols` to select a subset and avoid this error, skipping)
# Error parsing output/validation_sequences_9Feb2025/p06876/p06876_mut36/md_implicit/p06876_mut36_model_md.interactions.log the number of columns changed from 5 to 1 at row 464; use `usecols` to select a subset and avoid this error, skipping)

# %%
# get reference data
import pandas as pd
reference_csv_file = "raw_inputs/validation_sequences_9Feb2025.csv"
reference_df = pd.read_csv(reference_csv_file,keep_default_na=False)
# uniprot_id.lower(), wild_G0
reference_energies_dict = {}
reference_wild_G0_dict = {}
reference_nuc_length_dict = {}
name_count_dict = {}
reference_nuc_type_dict = {}
seq_index = {}
for index, row in reference_df.iterrows():
    name = row['uniprot_id'].lower()
    if name not in name_count_dict:
        name_count_dict[name] = 1
        seq_index[name] = len(name_count_dict)
    else:
        name_count_dict[name] += 1

    mutid = name_count_dict[name]
#(seq_index[name], row['ddG'])
    sequence_length = len(row['mutated_nucleotide_strand1'])
    reference_energies_dict[name+"_mut"+str(mutid)] = row['ddG']
    reference_nuc_length_dict[name+"_mut"+str(mutid)] = sequence_length
    reference_nuc_type_dict[name+"_mut"+str(mutid)] = row['nucleotide_sequence_type']
    reference_wild_G0_dict[name+"_mut"+str(mutid)] = row['wild_G0']


print(reference_energies_dict)
# Out:
# {'p32081_mut1': '0.48', 'p32081_mut2': '0.02', 'p32081_mut3': '0.34', 'p32081_mut4': '0.34', 'p32081_mut5': '0.98', 'p32081_mut6': '1.28', 'p32081_mut7': '0.42', 'p32081_mut8': '0.42', 'p32081_mut9': '0.72', 'q57468_mut1': '-0.43', 'q57468_mut2': '0', 'q57468_mut3': '0', 'q57468_mut4': '1.28', 'q57468_mut5': '0', 'q57468_mut6': '0.85', 'q57468_mut7': '0.85', 'q57468_mut8': '1.28', 'q57468_mut9': '0.85', 'q57468_mut10': '1.28', 'q57468_mut11': '1.28', 'q57468_mut12': '1.28', 'q57468_mut13': '1.28', 'q57468_mut14': '1.28', 'q57468_mut15': '1.28', 'q57468_mut16': '1.28', 'q57468_mut17': '1.28', 'q57468_mut18': '-0.43', 'q57468_mut19': '0', 'p16117_mut1': '-6.17', 'p16117_mut2': '-5.76', 'p16117_mut3': '-5.76', 'p03049_mut1': '3.94', 'p03049_mut2': '2.73', 'p03049_mut3': '2.09', 'p03049_mut4': '3.03', 'p03049_mut5': '2.48', 'p03049_mut6': '3.4', 'p03049_mut7': '3.45', 'p04891_mut1': '-9.9', 'p04891_mut2': '-7.4', 'p04891_mut3': '-7.4', 'p04891_mut4': '1.14', 'p03045_mut1': '0.33', 'p03045_mut2': '-0.05', 'p03045_mut3': '-0.9', 'p03045_mut4': '1.7', 'p03045_mut5': '-0.25', 'p03045_mut6': '0.33', 'p03045_mut7': '1.31', 'p03045_mut8': '0.3', 'p03045_mut9': '0.65', 'p03045_mut10': '1.93', 'p03045_mut11': '-0.45', 'p03045_mut12': '3.2', 'p03045_mut13': '0.55', 'p03045_mut14': '1.37', 'p03045_mut15': '1.7', 'p04891_mut5': '-0.93', 'p04891_mut6': '1.52', 'p04891_mut7': '-0.93', 'p04891_mut8': '-0.54', 'p04891_mut9': '1.52', 'p03045_mut16': '2.67', 'p03045_mut17': '2.67', 'p03045_mut18': '1.53', 'p03045_mut19': '2.67', 'p03045_mut20': '-1.52', 'p0a6r3_mut1': '1.4', 'p0a6r3_mut2': '0.75', 'p0a6r3_mut3': '0', 'p0a6r3_mut4': '2.97', 'p0a6r3_mut5': '0.55', 'p0a6r3_mut6': '0.25', 'p0a6r3_mut7': '0.66', 'p0a6r3_mut8': '0.55', 'p0a6r3_mut9': '0.25', 'p0a6r3_mut10': '0.55', 'p0a6r3_mut11': '0.55', 'p0a6r3_mut12': '0.42', 'p0a6r3_mut13': '1.37', 'p0a6r3_mut14': '2.76', 'p0a6r3_mut15': '0.66', 'p0a6r3_mut16': '-0.17', 'p0a6r3_mut17': '1.61', 'q7db51_mut1': '-0.03', 'q7db51_mut2': '0.13', 'q7db51_mut3': '0.48', 'q7db51_mut4': '0.53', 'q7db51_mut5': '0.25', 'q7db51_mut6': '0.12', 'q7db51_mut7': '0.43', 'q7db51_mut8': '0.15', 'q7db51_mut9': '0.16', 'q7db51_mut10': '0.17', 'p03612_mut1': '-2.73', 'p0a9h1_mut1': '-1.5', 'p05725_mut1': '-0.07', 'p05725_mut2': '-1.47', 'q9h2h0_mut1': '-0.17', 'q9h2h0_mut2': '-0.41', 'q9h2h0_mut3': '0', 'q01130_mut1': '0.34', 'q01130_mut2': '0.26', 'q01130_mut3': '1.21', 'q01130_mut4': '1.42', 'q01130_mut5': '1.82', 'q01130_mut6': '0.18', 'q01130_mut7': '1.95', 'q01130_mut8': '0.18', 'q01130_mut9': '0.14', 'q01130_mut10': '0.23', 'q01130_mut11': '2.06', 'q01130_mut12': '2.56', 'q01130_mut13': '2.31', 'p30014_mut1': '-0.04', 'p30014_mut2': '0.18', 'p30014_mut3': '0.49', 'p30014_mut4': '0.52', 'p30014_mut5': '-0.03', 'p30014_mut6': '0.03', 'p30014_mut7': '0.85', 'p30014_mut8': '1.17', 'p30014_mut9': '1.63', 'o59282_mut1': '0.06', 'o59282_mut2': '0.12', 'o59282_mut3': '0.91', 'o59282_mut4': '0.57', 'o59282_mut5': '0.72', 'o59282_mut6': '0.7', 'o59282_mut7': '0.66', 'o59282_mut8': '0.73', 'o59282_mut9': '0.53', 'o59282_mut10': '1.01', 'o59282_mut11': '0.21', 'o59282_mut12': '0.87', 'o59282_mut13': '2.25', 'p0acj8_mut1': '-0.4', 'p0acj8_mut2': '0.35', 'o45189_mut1': '1.83', 'o45189_mut2': '2.57', 'o45189_mut3': '2.38', 'o45189_mut4': '1.49', 'o45189_mut5': '1.91', 'o45189_mut6': '1.91', 'o45189_mut7': '2.12', 'o45189_mut8': '1.92', 'o45189_mut9': '2.13', 'o45189_mut10': '2.09', 'o45189_mut11': '1.84', 'o45189_mut12': '1.64', 'o45189_mut13': '1.86', 'o45189_mut14': '1.55', 'o45189_mut15': '2.05', 'o45189_mut16': '1.69', 'o45189_mut17': '1.92', 'q9h9z2_mut1': '0.88', 'p03034_mut1': '0.4', 'p03034_mut2': '1', 'p03034_mut3': '0.4', 'p03034_mut4': '0.2', 'p03034_mut5': '0.8', 'p03034_mut6': '0.5', 'p03034_mut7': '1.4', 'p03034_mut8': '0.6', 'p03034_mut9': '0.4', 'p03034_mut10': '1', 'p03034_mut11': '1', 'p03034_mut12': '0.4', 'p03034_mut13': '0.5', 'p03034_mut14': '2.8', 'p03034_mut15': '3.6', 'p03034_mut16': '0.9', 'p03034_mut17':  ...

# %%
# loop over keys in data containing 'mut' and check if same mutant has a 'ref' entry
# if so, calculate the difference between the two
import json
# create a pandas data frame with the following columns: uniprot_id, mut_id, ddG, ddG_pred
results_df = pd.DataFrame(columns=['uniprot_id','mut_id','nuc_type','ddG','ddG_measured','frac_ddG_measured' 'nuc_length', 'frac_ddG', 'mut_dG_measured','mut_avg_dG','pair_ptm'])

for key in data.keys():
    if key.find('mut')>0:
        uniprot_id = key.split('_')[0]
        ref_key = "_".join([uniprot_id,'ref'])

        if ref_key in data:
            mutant_data = data[key]
            ref_data = data[ref_key]
            if not len(mutant_data) == 2501 and len(ref_data)==2501:
                print(f"Skipping {key} because MD did not finish")
            
            mut_avg_energy = np.mean(mutant_data[len(mutant_data)//2:,-1])
            ref_avg_energy = np.mean(ref_data[len(ref_data)//2:,-1])
            ddG = mut_avg_energy - ref_avg_energy
            ddG_kcal = ddG/4.184
            G0 = float(reference_wild_G0_dict[key])
            mut_id = int(key.split('_')[1].replace("mut",""))
            ddG_measured = reference_energies_dict[key]
            
            if G0 != 0 and len(ddG_measured)>0:
                frac_ddG_measured = float(ddG_measured)/G0
                mut_dG_measured = float(ddG_measured) + G0
            else:
                frac_ddG_measured = np.nan

            nuc_length = reference_nuc_length_dict[key]
            nuc_type = reference_nuc_type_dict[key]

            frac_ddG = ddG_kcal/ref_avg_energy

            # read in the file named like {results_dir}/{name}/{name}+_mut{str(mutid)}}/*_summary_confidences.json
            summary_confidences_file = glob.glob(os.path.join(results_dir,uniprot_id,key,"*_summary_confidences.json"))[0]
            #print(summary_confidences_file)
            with open(summary_confidences_file) as f:
                summary_confidences = json.load(f)
                pair_iptm_list = summary_confidences["chain_pair_iptm"] 
                pair_ptm = pair_iptm_list[0][1]

            if len(ddG_measured)>0:
                results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
                #print(results_df)
                #pd.concat([results_df, {'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm }],ignore_index=True)
                
            else:
                print(f"no ddG for {key}")
    else:
        pass
# Out:
# no ddG for p03332_mut2
# no ddG for p03332_mut1
# no ddG for p03332_mut4
# no ddG for p03332_mut3
# no ddG for p03332_mut5
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# ...
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)
# /state/partition1/job-58761171/ipykernel_941519/2918647448.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'uniprot_id':uniprot_id,'mut_id':mut_id,'nuc_type':nuc_type, 'ddG':ddG_kcal,'ddG_measured':float(ddG_measured), 'frac_ddG_measured':frac_ddG_measured, 'nuc_length':nuc_length, 'frac_ddG': frac_ddG, 'mut_dG_measured':mut_dG_measured,  'mut_avg_dG':mut_avg_energy, 'pair_ptm':pair_ptm },ignore_index=True)

# %%
results_df.head()
# get the min and max of the column ddG_measured
min_ddG = results_df['ddG_measured'].min()
max_ddG = results_df['ddG_measured'].max()
print(min_ddG, max_ddG)
print(len(results_df))
print(reference_nuc_type_dict)
# Out:
# -9.9 7.69
# 479
# {'p32081_mut1': 'RNA', 'p32081_mut2': 'RNA', 'p32081_mut3': 'RNA', 'p32081_mut4': 'RNA', 'p32081_mut5': 'RNA', 'p32081_mut6': 'RNA', 'p32081_mut7': 'RNA', 'p32081_mut8': 'RNA', 'p32081_mut9': 'RNA', 'q57468_mut1': 'DNA', 'q57468_mut2': 'DNA', 'q57468_mut3': 'DNA', 'q57468_mut4': 'DNA', 'q57468_mut5': 'DNA', 'q57468_mut6': 'DNA', 'q57468_mut7': 'DNA', 'q57468_mut8': 'DNA', 'q57468_mut9': 'DNA', 'q57468_mut10': 'DNA', 'q57468_mut11': 'DNA', 'q57468_mut12': 'DNA', 'q57468_mut13': 'DNA', 'q57468_mut14': 'DNA', 'q57468_mut15': 'DNA', 'q57468_mut16': 'DNA', 'q57468_mut17': 'DNA', 'q57468_mut18': 'DNA', 'q57468_mut19': 'DNA', 'p16117_mut1': 'DNA', 'p16117_mut2': 'DNA', 'p16117_mut3': 'DNA', 'p03049_mut1': 'DNA', 'p03049_mut2': 'DNA', 'p03049_mut3': 'DNA', 'p03049_mut4': 'DNA', 'p03049_mut5': 'DNA', 'p03049_mut6': 'DNA', 'p03049_mut7': 'DNA', 'p04891_mut1': 'RNA', 'p04891_mut2': 'RNA', 'p04891_mut3': 'RNA', 'p04891_mut4': 'RNA', 'p03045_mut1': 'RNA', 'p03045_mut2': 'RNA', 'p03045_mut3': 'RNA', 'p03045_mut4': 'RNA', 'p03045_mut5': 'RNA', 'p03045_mut6': 'RNA', 'p03045_mut7': 'RNA', 'p03045_mut8': 'RNA', 'p03045_mut9': 'RNA', 'p03045_mut10': 'RNA', 'p03045_mut11': 'RNA', 'p03045_mut12': 'RNA', 'p03045_mut13': 'RNA', 'p03045_mut14': 'RNA', 'p03045_mut15': 'RNA', 'p04891_mut5': 'RNA', 'p04891_mut6': 'RNA', 'p04891_mut7': 'RNA', 'p04891_mut8': 'RNA', 'p04891_mut9': 'RNA', 'p03045_mut16': 'RNA', 'p03045_mut17': 'RNA', 'p03045_mut18': 'RNA', 'p03045_mut19': 'RNA', 'p03045_mut20': 'RNA', 'p0a6r3_mut1': 'DNA', 'p0a6r3_mut2': 'DNA', 'p0a6r3_mut3': 'DNA', 'p0a6r3_mut4': 'DNA', 'p0a6r3_mut5': 'DNA', 'p0a6r3_mut6': 'DNA', 'p0a6r3_mut7': 'DNA', 'p0a6r3_mut8': 'DNA', 'p0a6r3_mut9': 'DNA', 'p0a6r3_mut10': 'DNA', 'p0a6r3_mut11': 'DNA', 'p0a6r3_mut12': 'DNA', 'p0a6r3_mut13': 'DNA', 'p0a6r3_mut14': 'DNA', 'p0a6r3_mut15': 'DNA', 'p0a6r3_mut16': 'DNA', 'p0a6r3_mut17': 'DNA', 'q7db51_mut1': 'DNA', 'q7db51_mut2': 'DNA', 'q7db51_mut3': 'DNA', 'q7db51_mut4': 'DNA', 'q7db51_mut5': 'DNA', 'q7db51_mut6': 'DNA', 'q7db51_mut7': 'DNA', 'q7db51_mut8': 'DNA', 'q7db51_mut9': 'DNA', 'q7db51_mut10': 'DNA', 'p03612_mut1': 'RNA', 'p0a9h1_mut1': 'DNA', 'p05725_mut1': 'DNA', 'p05725_mut2': 'DNA', 'q9h2h0_mut1': 'DNA', 'q9h2h0_mut2': 'DNA', 'q9h2h0_mut3': 'DNA', 'q01130_mut1': 'RNA', 'q01130_mut2': 'RNA', 'q01130_mut3': 'RNA', 'q01130_mut4': 'RNA', 'q01130_mut5': 'RNA', 'q01130_mut6': 'RNA', 'q01130_mut7': 'RNA', 'q01130_mut8': 'RNA', 'q01130_mut9': 'RNA', 'q01130_mut10': 'RNA', 'q01130_mut11': 'RNA', 'q01130_mut12': 'RNA', 'q01130_mut13': 'RNA', 'p30014_mut1': 'DNA', 'p30014_mut2': 'DNA', 'p30014_mut3': 'DNA', 'p30014_mut4': 'DNA', 'p30014_mut5': 'DNA', 'p30014_mut6': 'DNA', 'p30014_mut7': 'DNA', 'p30014_mut8': 'DNA', 'p30014_mut9': 'DNA', 'o59282_mut1': 'RNA', 'o59282_mut2': 'RNA', 'o59282_mut3': 'RNA', 'o59282_mut4': 'RNA', 'o59282_mut5': 'RNA', 'o59282_mut6': 'RNA', 'o59282_mut7': 'RNA', 'o59282_mut8': 'RNA', 'o59282_mut9': 'RNA', 'o59282_mut10': 'RNA', 'o59282_mut11': 'RNA', 'o59282_mut12': 'RNA', 'o59282_mut13': 'RNA', 'p0acj8_mut1': 'DNA', 'p0acj8_mut2': 'DNA', 'o45189_mut1': 'DNA', 'o45189_mut2': 'DNA', 'o45189_mut3': 'DNA', 'o45189_mut4': 'DNA', 'o45189_mut5': 'DNA', 'o45189_mut6': 'DNA', 'o45189_mut7': 'DNA', 'o45189_mut8': 'DNA', 'o45189_mut9': 'DNA', 'o45189_mut10': 'DNA', 'o45189_mut11': 'DNA', 'o45189_mut12': 'DNA', 'o45189_mut13': 'DNA', 'o45189_mut14': 'DNA', 'o45189_mut15': 'DNA', 'o45189_mut16': 'DNA', 'o45189_mut17': 'DNA', 'q9h9z2_mut1': 'RNA', 'p03034_mut1': 'DNA', 'p03034_mut2': 'DNA', 'p03034_mut3': 'DNA', 'p03034_mut4': 'DNA', 'p03034_mut5': 'DNA', 'p03034_mut6': 'DNA', 'p03034_mut7': 'DNA', 'p03034_mut8': 'DNA', 'p03034_mut9': 'DNA', 'p03034_mut10': 'DNA', 'p03034_mut11': 'DNA', 'p03034_mut12': 'DNA', 'p03034_mut13': 'DNA', 'p03034_mut14': 'DNA', 'p03034_mut15': 'DNA', 'p03034_mut16': 'DNA', 'p03034_mut17': 'DNA', 'p03034_mut18': 'DNA', 'p03034_mut19': 'DNA', 'p03034_mut20': 'DNA', 'p03034_mut21': 'DNA', 'p03034_mut22': 'DNA', 'p03034_mut23': 'DNA', ' ...

# %%
# use seaborn to make a scatter plot of ddG_per vs ddG_measured
import seaborn as sns
import matplotlib.pyplot as plt


#get pearson correlation coefficient between these two columns
from scipy.stats import pearsonr
frac_ddG = results_df['frac_ddG']
frac_ddG_measured = results_df['frac_ddG_measured']

# get the uniprot of the ones with frac_ddG > 1.5
print("Largest errors:", results_df[results_df['frac_ddG']>1.5]['uniprot_id'].unique())

# remove nans from frac_ddG_measured in both
frac_ddG = frac_ddG[~np.isnan(frac_ddG_measured)]
frac_ddG_measured = frac_ddG_measured[~np.isnan(frac_ddG_measured)]

corr, _ = pearsonr(frac_ddG,frac_ddG_measured)
print(f"Correlation coefficient: {corr}")

plt.figure(figsize=(5,5))
# color by uniprot_id
# use squares if nuc_type is 'DNA' and circles if nuc_type is 'RNA'
sns.scatterplot(data=results_df,x='frac_ddG',y='frac_ddG_measured',hue='uniprot_id',style='nuc_type',markers={'DNA':'s','RNA':'o'})

#set x range to -10,10
#plt.xlim(-10,10)
#turn of legend
plt.legend().remove()
plt.ylabel("Relative $\Delta \Delta G_{measured}$")
plt.xlabel("Relative $\Delta \Delta G_{pred}$")
#add r^2 to the plot, with larger font size and in the top right corner
plt.text(0.7,0.9,f"$r^2 = {corr**2:.2f}$",transform=plt.gca().transAxes,fontsize=12)

#plt.xlabel("$\Delta \Delta G_{pred}$ per Nuc length (kcal/mol)")
#plt.ylabel("$\Delta \Delta G_{measured}$ (kcal/mol) (?)")
#plt.yticks(np.arange(-10,10,2))
# Out:
# Largest errors: ['p04390']
# Correlation coefficient: 0.18026658233071882
# Text(0.7, 0.9, '$r^2 = 0.03$')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, width_ratios=[3, 1], figsize=(3.5,3))

fig.subplots_adjust(wspace=0.05)  # adjust space between Axes
sns.scatterplot(data=results_df, x='frac_ddG', y='frac_ddG_measured', hue='uniprot_id', style='nuc_type', markers={'DNA':'s','RNA':'o'}, ax=ax1)
sns.scatterplot(data=results_df, x='frac_ddG', y='frac_ddG_measured', hue='uniprot_id', style='nuc_type', markers={'DNA':'s','RNA':'o'}, ax=ax2)
ax1.legend().remove()
ax2.legend().remove()
ax1.set_xlim(-0.3,0.3)
ax2.set_xlim(2.5,3)

# hide the spines between ax and ax2
ax1.spines.right.set_visible(False)
ax2.spines.left.set_visible(False)
#ax1.yaxis.tick_top()
ax1.tick_params(labelright=False)  # don't put tick labels at the top
ax2.yaxis.tick_right()
# 
ax1.set_ylabel("Relative $\Delta \Delta G_\\mathrm{measured}$")
ax1.set_xlabel("Relative $\Delta \Delta G_\\mathrm{pred}$")
ax2.set_xlabel("")


d = .7  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax1.plot([1, 1], [0, 1], transform=ax1.transAxes, **kwargs)
ax2.plot([0, 0], [1, 0], transform=ax2.transAxes, **kwargs)

plt.text(0,0.9,f"$r^2 = {corr**2:.2f}$",transform=plt.gca().transAxes,fontsize=12)
plt.tight_layout()
plt.savefig(os.path.join(results_dir,"relative_ddG_pred_vs_measured_complete.pdf"),dpi=300)

# %%
mut_dG_measured = results_df['mut_dG_measured']
mut_avg_dG = results_df['mut_avg_dG']

#divide by nuc length
mut_avg_dG_perlength = mut_avg_dG/results_df['nuc_length']

# remove nans from frac_ddG_measured in both
mut_dG_measured = mut_dG_measured[~np.isnan(mut_dG_measured)]
mut_avg_dG = mut_avg_dG[~np.isnan(mut_dG_measured)]
corr, _ = pearsonr(mut_avg_dG,mut_dG_measured)
print(f"Correlation coefficient: {corr}")

plt.figure(figsize=(3,3))
# color by uniprot_id
# use squares if nuc_type is 'DNA' and circles if nuc_type is 'RNA'
sns.scatterplot(data=results_df,x='mut_avg_dG',y='mut_dG_measured',hue='uniprot_id',style='nuc_type',markers={'DNA':'s','RNA':'o'})

#set x range to -10,10
#plt.xlim(-10,10)
#turn of legend
plt.legend().remove()


#add r^2 to the plot, with larger font size and in the top right corner
plt.text(0.1,0.9,f"$r^2 = {corr**2:.2f}$",transform=plt.gca().transAxes,fontsize=12)

plt.xlabel("$\Delta E_\\mathrm{pred}$ (kcal/mol)")
plt.ylabel("$\Delta G_\\mathrm{measured}$ (kcal/mol)")
#plt.yticks(np.arange(-10,10,2))
plt.tight_layout()
plt.savefig(os.path.join(results_dir,"dG_pred_vs_measured_complete.pdf"),dpi=300)
# Out:
# Correlation coefficient: 0.35075833918857724

# %%
from scipy.stats import spearmanr


# make the same plot as the previous cell but with x axis is ptm
dG_measured = results_df['mut_dG_measured']
ptm_predicted = results_df['pair_ptm']

print(ptm_predicted)


# remove nans from frac_ddG_measured in both
#ptm_predicted = ptm_predicted[~np.isnan(frac_ddG_measured)]
#frac_ddG_measured = frac_ddG_measured[~np.isnan(frac_ddG_measured)]

corr, _ = pearsonr(ptm_predicted,dG_measured)
spear_corr, _ = spearmanr(ptm_predicted,dG_measured)

print(f"Correlation coefficient: {corr}")
print(f"Spearman correlation coefficient: {spear_corr}")

plt.figure(figsize=(3,3))
# color by uniprot_id
# use squares if nuc_type is 'DNA' and circles if nuc_type is 'RNA'
sns.scatterplot(data=results_df,x='pair_ptm',y='mut_dG_measured',hue='uniprot_id',style='nuc_type',markers={'DNA':'s','RNA':'o'})

plt.legend().remove()
plt.ylabel("$\\Delta G_\\mathrm{measured}$")
plt.xlabel("AF3 pair-ptm")
#add r^2 to the plot, with larger font size and in the top right corner
plt.text(0.1,0.9,f"$K = {corr**2:.2f}$",transform=plt.gca().transAxes,fontsize=12)
plt.tight_layout()
plt.savefig(os.path.join(results_dir,"dG_measured_vs_af3_ptm_complete.pdf"),dpi=300)
# Out:
# 0      0.83
# 1      0.90
# 2      0.59
# 3      0.88
# 4      0.82
#        ...
# 474    0.36
# 475    0.36
# 476    0.89
# 477    0.92
# 478    0.88
# Name: pair_ptm, Length: 479, dtype: float64
# Correlation coefficient: 0.0939558259404736
# Spearman correlation coefficient: 0.011759406559602037
